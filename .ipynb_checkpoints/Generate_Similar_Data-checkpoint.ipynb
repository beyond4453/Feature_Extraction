# %%
import graphlab
import numpy as np
import pandas as pd
# Out:
# A newer version of GraphLab Create (v1.8.5) is available! Your current version is v1.7.1.
#
# You can use pip to upgrade the graphlab-create package. For more information see https://dato.com/products/create/upgrade.

# %%
best_answer = pd.read_csv('./DIVIDE/MATCH/best_answer.csv')
second_answer = pd.read_csv('./DIVIDE/MATCH/second_answer.csv')
third_answer = pd.read_csv('./DIVIDE/MATCH/third_answer.csv')

# %%
init_qid = best_answer['question_id']
init_qc = best_answer['question_content']
init_qt = best_answer['question_tags']

# %%
# best_answer    # 1959 rows × 18 columns

# %% [markdown]
# # Use KNN Model Find Similar Question Content

# %%
question_content = best_answer[['question_id','question_content','question_tags']]   # 1959 rows × 3 columns

# %%
# question_content
question_content.to_csv('./DIVIDE/SIMILAR/Question_Content.csv', encoding='utf-8', index = False)

# %%
# Use graphlab to read question_content
question_content = graphlab.SFrame.read_csv('./DIVIDE/SIMILAR/Question_Content.csv')
# Out:
# [INFO] 1460952790 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_FILE to /home/zpgao/anaconda2/lib/python2.7/site-packages/certifi/cacert.pem
# 1460952790 : INFO:     (initialize_globals_from_environment:282): Setting configuration variable GRAPHLAB_FILEIO_ALTERNATIVE_SSL_CERT_DIR to
# This non-commercial license of GraphLab Create is assigned to beyond_acm@163.com and will expire on January 04, 2017. For commercial licensing options, visit https://dato.com/buy/.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-3773 - Server binary: /home/zpgao/anaconda2/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1460952790.log
# [INFO] GraphLab Server Version: 1.7.1
# PROGRESS: Finished parsing file /home/zpgao/ML/Best_Answer/Feature_Extraction/DIVIDE/SIMILAR/Question_Content.csv
# PROGRESS: Parsing completed. Parsed 100 lines in 0.027462 secs.
# ------------------------------------------------------
# Inferred types from first line of file as
# column_type_hints=[int,str,str]
# If parsing fails due to incorrect types, you can correct
# the inferred type list above and pass it to read_csv in
# the column_type_hints argument
# ------------------------------------------------------
# PROGRESS: Finished parsing file /home/zpgao/ML/Best_Answer/Feature_Extraction/DIVIDE/SIMILAR/Question_Content.csv
# PROGRESS: Parsing completed. Parsed 1959 lines in 0.009861 secs.

# %%
# question_content

# %%
# add 'text' && 'word_count' && 'tfidf' features
question_content['text'] = question_content['question_tags'] +  question_content['question_content'] 
question_content['word_count'] = graphlab.text_analytics.count_words(question_content['text'])
tfidf = graphlab.text_analytics.tf_idf(question_content['word_count'])
question_content['tfidf'] = tfidf

# %%
knn_model = graphlab.nearest_neighbors.create(question_content, features=['tfidf'], label='question_id')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %%
# question_content
# len( question_content ) 1959

# %%
# q0 = question_content[0:1]
# Similar_Qid_List is a dict 
# key : Index From 0 - 1958 
# value : Similar Qid List [Qid1, Qid2, Qid3, Qid4, Qid5]
# question_content[Index]['qustion_id'] = Qid1
Similar_Qid_List = {}
for i in range( len(question_content) ) :
    key = 'Q' + str(i) + '_Similar_List'
    Q_i = question_content[i:i+1]
    value = knn_model.query(Q_i, k=5)['reference_label']
    Similar_Qid_List[key] = value
# Out:
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 996us        |
# PROGRESS: | Done         |         | 100         | 1.866ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 1.032ms      |
# PROGRESS: | Done         |         | 100         | 7.671ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 1.107ms      |
# PROGRESS: | Done         |         | 100         | 2.157ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 6.136ms      |
# PROGRESS: | Done         |         | 100         | 7.448ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 832us        |
# PROGRESS: | Done         |         | 100         | 1.737ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 3.433ms      |
# PROGRESS: | Done         |         | 100         | 4.537ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 876us        |
# PROGRESS: | Done         |         | 100         | 1.908ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   |
ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 842us        |
# PROGRESS: | Done         |         | 100         | 1.972ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 803us        |
# PROGRESS: | Done         |         | 100         | 1.881ms      |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: Starting pairwise querying.
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.0510465   | 877us        |
# PROGRESS: | Done         |         | 100         | 2ms          |
# PROGRESS: +--------------+---------+-------------+--------------+

# %%
# Similar_Qid_List['Q0_Similar_List'][0]

# %%
Original_List = []
Similar1_List = []
Similar2_List = []
Similar3_List = []

for i in range( len(question_content) ) :
    key = 'Q' + str(i) + '_Similar_List'
    value = Similar_Qid_List[key][0]
    Original_List.append(value)
    
for i in range( len(question_content) ) :
    key = 'Q' + str(i) + '_Similar_List'
    value = Similar_Qid_List[key][1]
    Similar1_List.append(value)
    
for i in range( len(question_content) ) :
    key = 'Q' + str(i) + '_Similar_List'
    value = Similar_Qid_List[key][2]
    Similar2_List.append(value)
    
for i in range( len(question_content) ) :
    key = 'Q' + str(i) + '_Similar_List'
    value = Similar_Qid_List[key][3]
    Similar3_List.append(value)

# %%
# len( Original_List )  # 1959
# len( Similar1_List )  # 1959
# len( Similar2_List )  # 1959
# len( Similar3_List )  # 1959
# len( set(Similar1_List) )  # 1048
# len( set(Similar2_List) )  # 1044 
# len( set(Similar3_List) )  # 1062

# %%
Similar_best = best_answer[ best_answer['question_id'] == Similar1_List[0] ]
Similar_second = second_answer[ second_answer['question_id'] == Similar1_List[0] ]
Similar_third = third_answer[ third_answer['question_id'] == Similar1_List[0] ]

# %%
for i in range(1, len(question_content)) :
    
    Similar_best = Similar_best.append( best_answer[ best_answer['question_id'] == Similar1_List[i] ] )

# %%
for i in range(1, len(question_content)) :
    
    Similar_second = Similar_second.append( second_answer[ second_answer['question_id'] == Similar1_List[i] ] )

# %%
for i in range(1, len(question_content)) :
    
    Similar_third = Similar_third.append( third_answer[ third_answer['question_id'] == Similar1_List[i] ] )

# %%
# Similar_best # 1959 rows × 18 columns
# Similar_second # 1959 rows × 18 columns
# Similar_third # 1959 rows × 18 columns

# %%
Similar_best = Similar_best.reset_index()
Similar_best = Similar_best.drop('index', axis=1)

Similar_second = Similar_second.reset_index()
Similar_second = Similar_second.drop('index', axis=1)

Similar_third = Similar_third.reset_index()
Similar_third = Similar_third.drop('index', axis=1)

# %%
Similar_best['question_id'] = init_qid
Similar_best['question_content'] = init_qc
Similar_best['question_tags'] = init_qt

Similar_second['question_id'] = init_qid
Similar_second['question_content'] = init_qc
Similar_second['question_tags'] = init_qt

Similar_third['question_id'] = init_qid
Similar_third['question_content'] = init_qc
Similar_third['question_tags'] = init_qt

# %%
Similar_best.to_csv( './DIVIDE/SIMILAR/Similar_best.csv', encoding='utf-8', index = False)
Similar_second.to_csv( './DIVIDE/SIMILAR/Similar_second.csv', encoding='utf-8', index = False)
Similar_third.to_csv( './DIVIDE/SIMILAR/Similar_third.csv', encoding='utf-8', index = False)
